# %% [markdown]
# # Alaskan Census Area's Physcal Inactivity and Exercise Opportunites
#
# ## Brief Description
#
# ###### This repository contains a list of 45 measure of physical inactivity and access to excerise opportunities in Alaska between 2014 and 2015. Collecting several measures of "Public Health" standards accross multiple
# ## Table of Contents
# - Brief Desciption
# - Installation

# %% [markdown]
# #Installation
# *Step-by-step instructions on how to install and set up the project.*
#
#
# 1. Clone the Repository
#     - Clone the project repository from GitHub
#     -  <INSERT:  repository_url>
# 2. Download "CountyHealthData_2014-2015.csv"
# 3. Open Google Colab
# 4. Create New Notebook

# %% [markdown]
# #Mounting GoogleDrive
# 5.  To mount GoogleDrive
#     - On the left-hand side of the screen in the sidebar select the file icon, the fourth down.
#     - From the new popout that reads "Files" select the GoogleDrive icon, the third icon of the top row.
#     - From here allow connection to GoogleDrive
#     - The process of mounting the GoogleDrive will take a moment
# 6. Once GoogleDrive is mounted select "drive", "MyDrive", "CountyHealthData_2014-2015.csv"
#     - Click the play button on the left hand side of the code box to run code.

# %% [markdown]
# #Accessing GoogleDrive
#
# 7. In the large code space begin a new code with "+ Code"
# 8. To establish connectivity to file
#     - write "from google.colab import drive"
#     - Next line "drive.mount('/content/My_Drive')"
#     -  Click the play button on the left hand side of the code box to run code.
#     - A pop up to permit this notebook to access GoogleDrive will occur, allow connection
#         - You will have to select continue a few times in order to allow connection

# %%
from google.colab import drive
drive.mount('/content/unit3')
# Out:
# Mounted at /content/unit3

# %% [markdown]
# #Packages
# 9. To install proper software to analyze our data insert a new line of code with "+ Code"
#     - This code will read "import numpy as np"
#     - In the next line "import pandas as pd"
#     - Click the play button on the left hand side of the code box to run code.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #Creating a Dataframe
# 10. To establish a dataframe we will insert a new line of code with "+ Code".
#     - This code will read, "df = pd.read_csv("MyDrive/CountyHealthData_2014-2015.csv")"
#     - Click the play button on the left hand side of the code box to run code.

# %%
df = pd.read_csv("unit3/MyDrive/CountyHealthData_2014-2015.csv")

# %% [markdown]
# #Exploring the Dataframe
# 11. From here to narrow down the larger data set into something more usuable and easily managed we will create a random sample of 50 responces.
#     - These 46 will be consistant for everyone
#     - Create a new line of code with the selection of "+ Code." In it we will type "df.loc[:,["County", "Year", "Physical inactivity", "Access to exercise opportunities"]].head(n=46)"
#     - Click the play button on the left hand side of the code box to run code.
#     - From here a chart should appear

# %%
 df.loc[:,["County", "Year", "Physical inactivity", "Access to exercise opportunities"]].head(n=46)
# Out:
#                                          County      Year  \
# 0                    Aleutians West Census Area  1/1/2014
# 1                    Aleutians West Census Area  1/1/2015
# 2                             Anchorage Borough  1/1/2014
# 3                             Anchorage Borough  1/1/2015
# 4                            Bethel Census Area  1/1/2014
# 5                            Bethel Census Area  1/1/2015
# 6                        Dillingham Census Area  1/1/2014
# 7                        Dillingham Census Area  1/1/2015
# 8                  Fairbanks North Star Borough  1/1/2014
# 9                  Fairbanks North Star Borough  1/1/2015
# 10                               Haines Borough  1/1/2014
# 11                               Haines Borough  1/1/2015
# 12                               Juneau Borough  1/1/2014
# 13                               Juneau Borough  1/1/2015
# 14                      Kenai Peninsula Borough  1/1/2014
# ...

# %% [markdown]
# #Saving Work in Colab
# 12. Past work from each session in Colab will save. However in coming back to it at a later time you will have to re-run each code box and with that re-allow connection to GoogleDrive through the pop up that appears in Step 8.

# %% [markdown]
# Saving Chart to Device
# 13. To save the data from your created chart we will insert a new line of code wiht "+ Code"
#     - Cretaing a new line of code that will read "chart_data = df[["County", "Year", "Physical inactivity", "Access to exercise opportunities"]]".head(n=46)
#       - "chart_data" can be replaced with whatever you want your chart file to be saved with.
#     - Click the play button on the left hand side of the code box to run code.

# %%
chart_data = df[["County", "Year", "Physical inactivity", "Access to exercise opportunities"]].head(n=46)

# %% [markdown]
# 14. Insert a new line of code with "+ Code" to convert the chart to a CSV file
#     - Click the play button on the left hand side of the code box to run code.

# %%
chart_data.to_csv('chart_data.csv', index=False)

# %% [markdown]
# 15. Insert a final line of code with "+ Code" to save the CSV file to your device
#     - Line one will read
#     "from google.colab import files"
#     - Select the enter key moving to the next line within the same code box and write
#     "files.download('chart_data.csv')"
#     - Click the play button on the left hand side of the code box to run code.
#       - This saving the CSV file to your device under the ealier chosen name

# %%
from google.colab import files
files.download('chart_data.csv')
